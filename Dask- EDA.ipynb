# %%
import dask.dataframe as dd
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

import plotly
import plotly.graph_objs as go

# %%
def read_data(input_path):
    raw_data = dd.read_csv(input_path)
    return raw_data

# %%
data = read_data('https://gist.githubusercontent.com/aromerovilla/7170e4ff45dd943af6a920d2f510cd0f/raw/b5732e3122ca9d0dec95717b62434e2b68e642b6/hour.csv')

# %%
data.info()
data.dtypes
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 17 entries, instant to cnt
# dtypes: object(1), float64(4), int64(12)
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# hr              int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
daily = read_data('https://gist.githubusercontent.com/alombatti/60c99f57b916b5c121abbd713273ab86/raw/3618d0d08251995be6550e53980f0c5ffdbbf4c8/daydata.csv')

# %%
daily.info()
daily.dtypes
# Out:
# <class 'dask.dataframe.core.DataFrame'>
# Columns: 16 entries, instant to cnt
# dtypes: object(1), float64(4), int64(11)
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
daily = daily.sample(frac = 1.368, replace=True)
data = data.sample(frac = 1.368, replace=True)

# %%
daily.compute()
data.compute()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 6159      6160  2011-09-19       3   0     9   5        0        1
# 11318    11319  2012-04-21       2   1     4  19        0        6
# 12300    12301  2012-06-01       2   1     6  17        0        5
# 7118      7119  2011-10-29       4   0    10   5        0        6
# 503        504  2011-01-23       1   0     1   1        0        0
# 4427      4428  2011-07-08       3   0     7   9        0        5
# 5763      5764  2011-09-02       3   0     9  14        0        5
# 9943      9944  2012-02-24       1   1     2   8        0        5
# 11470    11471  2012-04-28       2   1     4   3        0        6
# 12742    12743  2012-06-20       2   1     6   3        0        3
# 4739      4740  2011-07-21       3   0     7   9        0        4
# 14667    14668  2012-09-08       3   1     9   8        0        6
# 8640      8641  2011-12-31       1   0    12  19        0        6
# 16226    16227  2012-11-13       4   1    11  20        0        2
# 15243    15244  2012-10-02       4   1    10   8        0        2
# 2145      2146  2011-04-04       2   0     4   6        0        1
# 14920    14921  2012-09-18       3   1     9  21        0        2
# 10454    10455  2012-03-16       1   1     3  17        0        5
# 15451    15452  2012-10-11       4   1    10   0        0        4
# 15079    15080  2012-09-25       4   1     9  12        0        2
# 9044      9045  2012-01-17       1   1     1  18        0        2
# 3605      3606  2011-06-04       2   0     6   3        0        6
# 1653      1654  2011-03-14       1   0     3  11        0        1
# 5279      5280  2011-08-12       3   0     8  21        0        5
# 15324    15325  2012-10-05       4   1    10  17        0        5
# 3147      3148  2011-05-16       2   0     5   1        0        1
# 4323      4324  2011-07-04       3   0     7   1        1        1
# 7            8  2011-01-01       1   0     1   7        0        6
# 2206      2207  2011-04-06       2   0     4  19        0        3
# 14364    14365  2012-08-26       3   1     8  17        0        0
# ...        ...         ...     ...  ..   ...  ..      ...      ...
#
# 7               0           1  0.20  0.2576  0.86     0.0000       1
# 2206            1           1  0.50  0.4848  0.31     0.2985      36
# 14364           0           1  0.64  0.5758  0.89     0.2239      61
# ...           ...         ...   ...     ...   ...        ...     ...
# 15398           0           2  0.40  0.4091  0.71     0.2537      38
# 11644           0           1  0.62  0.5909  0.78     0.1045      61
# 7080            1           2  0.52  0.5000  0.83     0.1045      12
# 1141            0           1  0.20  0.2273  0.51     0.1045       2
# 11166           0           1  0.62  0.6212  0.46     0.2985     227
# 8609            1           1  0.32  0.3333  0.57     0.1343      38
# 5404            1           1  0.66  0.6212  0.65     0.2239       2
# 5804            0           1  0.66  0.6061  0.78     0.1940      10
# 5398            1           1  0.74  0.6818  0.58     0.2537      37
# 5767            1           2  0.68  0.6364  0.65     0.1940      50
# 6323            1           2  0.62  0.5606  0.88     0.1045       3
# 10880           1           1  0.52  0.5000  0.25     0.0000     101
# 16522           1           1  0.22  0.2727  0.69     0.0000       0
# 14543           0           1  0.66  0.5909  0.89     0.0896       6
# 17334           0           2  0.26  0.2273  0.56     0.4179       1
# 10473           0           1  0.56  0.5303  0.68     0.1642     286
# 11940           1           1  0.66  0.6212  0.31     0.1343     133
# 15882           0           3  0.42  0.4242  0.94     0.3582       2
# 15715           1           1  0.40  0.4091  0.62     0.0000       3
# 14734           1           1  0.48  0.4697  0.67     0.1343       1
# 8246            1           1  0.32  0.3182  0.66     0.1940       2
# 14718           1           1  0.62  0.6212  0.43     0.2985      69
# 3861            1           1  0.64  0.6212  0.50     0.3582      51
# 14039           1           1  0.64  0.6061  0.69     0.1045       0
# 2823            1           2  0.62  0.6061  0.69     0.1940      51
# 14762           1           1  0.52  0.5000  0.72     0.0000      24
# 8726            1           1  0.06  0.1061  0.45     0.0000       7
# 9875            1           2  0.30  0.2727  0.56     0.3881      16
# 8276            1           2  0.34  0.3030  0.42     0.3582      10
# 13480           1           3  0.62  0.5758  0.83     0.3284      14
#
#        registered  cnt
# 6159           26   28
# 11318          45   54
# 12300         202  227
# 7118            1    1
# 503            12   13
# 4427          211  241
# 5763          208  283
# 9943          452  469
# 11470          23   26
# 12742           6    8
# 4739          166  200
# 14667         197  230
# 8640           73   92
# 16226         211  223
# 15243         128  134
# 2145           43   46
# 14920         186  207
# 10454         235  258
# 15451          41   42
# 15079         233  302
# 9044          451  463
# 3605           10   18
# 1653           45   71
# 5279          153  226
# 15324         742  900
# 3147            8   14
# 4323           76  119
# 7               2    3
# 2206          196  232
# 14364         172  233
# ...           ...  ...
# 15398         333  371
# 11644         223  284
# 7080           95  107
# 1141           22   24
# 11166         301  528
# 8609          159  197
# 5404            4    6
# 5804           20   30
# 5398          243  280
# 5767          305  355
# 6323           14   17
# 10880         230  331
# 16522          10   10
# 14543           5   11
# 17334          14   15
# 10473         365  651
# 11940         719  852
# 15882          12   14
# 15715          28   31
# 14734           7    8
# 8246           90   92
# 14718         167  236
# 3861          335  386
# 14039          11   11
# 2823          119  170
# 14762         533  557
# 8726           57   64
# 9875          147  163
# 8276          163  173
# 13480         108  122
#
# [23774 rows x 17 columns]

# %%
# Configuring plotting visual and sizes
sns.set_style('white')
sns.set_context('talk')
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (30, 10),
          'axes.labelsize': 'x-large',
          'axes.titlesize':'x-large',
          'xtick.labelsize':'x-large',
          'ytick.labelsize':'x-large'}

plt.rcParams.update(params)

# %%
season_col = ["#749ee8", '#ffc9b9','#e69479','#b2d7ff']
month_col = ["#749ee8","#749ee8","#749ee8", '#ffc9b9','#ffc9b9','#ffc9b9','#e69479','#e69479','#e69479','#b2d7ff','#b2d7ff','#b2d7ff']

# %%
fig, ax = plt.subplots()
monthly_plot = sns.barplot(data = data[['mnth',
                                        'cnt']],
                           x = 'mnth',
                           y = 'cnt',
                           ci = None,
                           palette=month_col,
                           estimator = sum)
ax.set(xlabel = 'Month of the year', ylabel = 'Total count of bikes', title = 'Total count of bikes per month')
ax.set_xticklabels(['Jan','Feb','Mar','Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-c7d7adff7d06> in <module>()
#       6                            ci = None,
#       7                            palette=month_col,
# ----> 8                            estimator = sum)
#       9 ax.set(xlabel = 'Month of the year', ylabel = 'Total count of bikes', title = 'Total count of bikes per month')
#      10 ax.set_xticklabels(['Jan','Feb','Mar','Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     144             # See if we need to get variables from `data`
#     145             if data is not None:
# --> 146                 x = data.get(x, x)
#     147                 y = data.get(y, y)
#     148                 hue = data.get(hue, hue)
#
# ~/anaconda3/lib/python3.6/site-packages/dask/dataframe/core.py in __getattr__(self, key)
#    2634             return self[key]
#    2635         else:
# -> 2636             raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    2637
#    2638     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'get'

# %%
# Number of bikes rented per season
fig, ax = plt.subplots()
plot = sns.barplot('yr',
                   'cnt',
                   hue = 'season',
                   data = data,
                   ci = None,
                   palette=season_col,
                   estimator = sum)
ax.set(xlabel = 'Year', ylabel = 'Bikes rented',title = 'Bikes rented per year and per season')
ax.set_xticklabels(['2011', '2012'])
leg_handles = ax.get_legend_handles_labels()[0]
ax.legend(leg_handles, ["Winter", "Spring", "Summer", "Autumn"])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-82-76c8f6b32dbd> in <module>()
#       7                    ci = None,
#       8                    palette=season_col,
# ----> 9                    estimator = sum)
#      10 ax.set(xlabel = 'Year', ylabel = 'Bikes rented',title = 'Bikes rented per year and per season')
#      11 ax.set_xticklabels(['2011', '2012'])
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3147                           estimator, ci, n_boot, units,
#    3148                           orient, color, palette, saturation,
# -> 3149                           errcolor, errwidth, capsize, dodge)
#    3150
#    3151     if ax is None:
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     144             # See if we need to get variables from `data`
#     145             if data is not None:
# --> 146                 x = data.get(x, x)
#     147                 y = data.get(y, y)
#     148                 hue = data.get(hue, hue)
#
# ~/anaconda3/lib/python3.6/site-packages/dask/dataframe/core.py in __getattr__(self, key)
#    2634             return self[key]
#    2635         else:
# -> 2636             raise AttributeError("'DataFrame' object has no attribute %r" % key)
#    2637
#    2638     def __dir__(self):
#
# AttributeError: 'DataFrame' object has no attribute 'get'
